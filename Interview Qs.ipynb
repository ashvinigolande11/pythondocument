# %%
#complex

# %%
1.can we define list inside tuple?
Yes
list ---> mutable
tuple --> immutable

# %%
py_tuple = (1,2,3,4,[100,200,300],'python','java')

# %%
py_tuple[4].insert(1,'Hadoop')

# %%
py_tuple
# Out:
# (1, 2, 3, 4, [100, 'Hadoop', 200, 300], 'python', 'java')

# %%
py_list = [34,95,9,5,(1,2,3),'java',]

# %%
py_list
# Out:
# [34, 95, 9, 5, (1, 2, 3), 'java']

# %%
py_list[4].insert(2,900)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-0dd07f1022d2> in <module>
# ----> 1 py_list[4].insert(2,900)
#
# AttributeError: 'tuple' object has no attribute 'insert'

# %%
p = [1,[2,[3,[4,[5,[6]]]]]]

# %%
p[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-d9911783213f> in <module>
# ----> 1 p[5]
#
# IndexError: list index out of range

# %%
p[1][1][1][1][1][0]
# Out:
# 6

# %%
p
# Out:
# [1, [2, [3, [4, [5, [6]]]]]]

# %%
p[-1][-1]
# Out:
# [3, [4, [5, [6]]]]

# %%
p =[100,12]

# %%
p[1]
# Out:
# 12

# %%
p = (1,(2,3,4),600,(100,200,300))

# %%
p
# Out:
# (1, (2, 3, 4), 600, (100, 200, 300))

# %%
a = 10

# %%
b = 10

# %%
id(a)
# Out:
# 140713526831184

# %%
id(b)
# Out:
# 140713526831184

# %%
p = [1,2,3,10]

# %%
p1 = (1,2,3,10)

# %%
id(p)
# Out:
# 2102982274752

# %%
id(p1)
# Out:
# 2102994938352

# %%
#unpacking and packing

# %%
#in python we can assign multiple value

# %%
a = 10

# %%
id(a)
# Out:
# 140713526831184

# %%
a = 100

# %%
id(a)
# Out:
# 140713526834064

# %%
b = 10

# %%
id(b)
# Out:
# 140713526831184

# %%
a = 100,200,300,'python'

# %%
a
# Out:
# (100, 200, 300, 'python')

# %%
type(a)
# Out:
# tuple

# %%
a= 100

# %%
type(a)
# Out:
# int

# %%
a = 'python'

# %%
type(a)
# Out:
# str

# %%
a = 45.56

# %%
type(a)
# Out:
# float

# %%
temp = 100,45.98,'python'

# %%
temp
# Out:
# (100, 45.98, 'python')

# %%
a,b,c = temp

# %%
a
# Out:
# 100

# %%
b
# Out:
# 45.98

# %%
c
# Out:
# 'python'

# %%
p = ['c','java','hadoop']

# %%
p
# Out:
# ['c', 'java', 'hadoop']

# %%
x,y,z = p   #unpacking

# %%
x
# Out:
# 'c'

# %%
y
# Out:
# 'java'

# %%
z
# Out:
# 'hadoop'

# %%
d = x,y,z

# %%
d
# Out:
# ('c', 'java', 'hadoop')

# %%
x,y,z,m,k,l = d
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-0bdbfe57386a> in <module>
# ----> 1 x,y,z,m,k,l = d
#
# ValueError: not enough values to unpack (expected 6, got 3)

# %%
a,b,c,d = 100,200,300,400 #multiple assignment

# %%
a
# Out:
# 100

# %%
b
# Out:
# 200

# %%
c
# Out:
# 300

# %%
d
# Out:
# 400

# %%
 p =[1,2,3,54,6,6,8,9,4,9,5,90,]

# %%
# Out:
# [1, 3, 9, 9, 5]

# %%
id(p)
# Out:
# 2102997628480

# %%
id(p[1])
# Out:
# 140713526830928

# %%
username,password,port,url = ('admin','Admin@123',80,'www.google.com')

# %%
username
# Out:
# 'admin'

# %%
password
# Out:
# 'Admin@123'

# %%
t = [1,2,3]

# %%
tuple(t)
# Out:
# (1, 2, 3)

# %%
#more complex --->

# %%
t
# Out:
# [1, 2, 3]

# %%
t1 = (1,2,3)

# %%
t1 = list(t1)

# %%
type(t1)
# Out:
# list

# %%
t1.append(100)

# %%
tuple(t1)
# Out:
# (1, 2, 3, 100)

# %%
p = 'python'

# %%
list(p)
# Out:
# ['p', 'y', 't', 'h', 'o', 'n']

# %%
d = {'name':'Arun','id':101,'Sal':45000}

# %%
d
# Out:
# {'name': 'Arun', 'id': 101, 'Sal': 45000}

# %%
list(d)
# Out:
# ['name', 'id', 'Sal']

# %%
import pandas as pd

# %%
df = pd.read_csv('Bengaluru_House_Data.csv')

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.tail()
# Out:
#                   area_type   availability               location       size  \
# 13315        Built-up  Area  Ready To Move             Whitefield  5 Bedroom
# 13316  Super built-up  Area  Ready To Move          Richards Town      4 BHK
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar      2 BHK
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar      4 BHK
# 13319  Super built-up  Area  Ready To Move           Doddathoguru      1 BHK
#
#        society total_sqft  bath  balcony  price
# 13315  ArsiaEx       3453   4.0      0.0  231.0
# 13316      NaN       3600   5.0      NaN  400.0
# 13317  Mahla T       1141   2.0      1.0   60.0
# 13318  SollyCl       4689   4.0      1.0  488.0
# 13319      NaN        550   1.0      1.0   17.0

# %%
with open('Bengaluru_House_Data.csv','r') as fp:
    data = fp.read()

# %%
print(data)
# Out:
# area_type,availability,location,size,society,total_sqft,bath,balcony,price
# Super built-up  Area,19-Dec,Electronic City Phase II,2 BHK,Coomee ,1056,2,1,39.07
# Plot  Area,Ready To Move,Chikka Tirupathi,4 Bedroom,Theanmp,2600,5,3,120
# Built-up  Area,Ready To Move,Uttarahalli,3 BHK,,1440,2,3,62
# Super built-up  Area,Ready To Move,Lingadheeranahalli,3 BHK,Soiewre,1521,3,1,95
# Super built-up  Area,Ready To Move,Kothanur,2 BHK,,1200,2,1,51
# Super built-up  Area,Ready To Move,Whitefield,2 BHK,DuenaTa,1170,2,1,38
# Super built-up  Area,18-May,Old Airport Road,4 BHK,Jaades ,2732,4,,204
# Super built-up  Area,Ready To Move,Rajaji Nagar,4 BHK,Brway G,3300,4,,600
# Super built-up  Area,Ready To Move,Marathahalli,3 BHK,,1310,3,1,63.25
# Plot  Area,Ready To Move,Gandhi Bazar,6 Bedroom,,1020,6,,370
# Super built-up  Area,18-Feb,Whitefield,3 BHK,,1800,2,2,70
# Plot  Area,Ready To Move,Whitefield,4 Bedroom,Prrry M,2785,5,3,295
# ...

# %%
import csv

# %%
with open('Bengaluru_House_Data.csv') as fp:
    r =csv.reader(fp)
    data = tuple(r)

# %%
data
# Out:
# (['area_type',
#   'availability',
#   'location',
#   'size',
#   'society',
#   'total_sqft',
#   'bath',
#   'balcony',
#   'price'],
#  ['Super built-up  Area',
#   '19-Dec',
#   'Electronic City Phase II',
#   '2 BHK',
#   'Coomee ',
#   '1056',
#   '2',
#   '1',
#   '39.07'],
#  ['Plot  Area',
#   'Ready To Move',
#   'Chikka Tirupathi',
#   '4 Bedroom',
#   'Theanmp',
#   '2600',
#   '5',
#   '3',
#   '120'],
#  ['Built-up  Area',
#   'Ready To Move',
#   'Uttarahalli',
#   '3 BHK',
#   '',
#   '1440',
#   '2',
#   '3',
#   '62'],
#  ['Super built-up  Area',
#   'Ready To Move',
#   'Lingadheeranahalli',
#   '3 BHK',
#   'Soiewre',
#   '1521',
#   '3',
#   '1',
#   '95'],
#  ['Super built-up  Area',
#   'Ready To Move',
#   'Kothanur',
#   '2 BHK',
#   '',
#   '1200',
#   '2',
#   '1',
#   '51'],
#  ['Super built-up  Area',
#   'Ready To Move',
#   'Whitefield',
#   '2 BHK',
#   'DuenaTa',
#   '1170',
#   '2',
#   '1',
#   '38'],
#  ['Super built-up  Area',
#   '18-May',
# ...

# %%
import csv

# %%
with open('Client_prd.csv','w') as fp:
    w = csv.writer(fp)
    w.writerow(['id','name','sal'])
    for i in range(3):
        id =int(input("Enter the id:"))
        name = input("Enter the name")
        sal = input("Enter the sal")
        w.writerow([id,name,sal])
# Out:
# Enter the id:101
# Enter the namesuresh
# Enter the sal6522
# Enter the id:45
# Enter the namesadfsdaf
# Enter the sal454545
# Enter the id:6464
# Enter the nameasdfasdf
# Enter the sal151515

# %%
with open('Client_prd.csv') as fp:
    data = fp.read()
    print(data)
# Out:
# id,name,sal
#
# 101,suresh,6522
#
# 45,sadfsdaf,454545
#
# 6464,asdfasdf,151515

# %%
df = pd.read_csv('C:\\Users\\kanti\\OneDrive\\Desktop\\tested.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
import os

# %%
os.chdir('C:\\Users\\kanti\\OneDrive\\Desktop\\ML 2627')

# %%
df = pd.read_csv('temp.csv')

# %%
df
# Out:
#    Unnamed: 0      city  avg_pop
# 0           0      pune       23
# 1           1  banglore       66
# 2           2    mumbai      788
# 3           3      pune       46

# %%
Django -------------------->
DA/DS/ML/Python/Dajngo/ --->

# %%
need to Practice(2hr)
-------------------------->
